# %% [markdown]
# 离线计算 Word2Vec 的词向量。

# %% [markdown]
# 一、数据读入

# %% [markdown]
# 首先进行数据清洗。转换原始数据中的结构字符，并转为简体。

# %%
import re
import json
from zhconv import convert

with open('chinese-poetry/json/表面结构字.json', 'r', encoding='utf-8') as f:
    stru = json.load(f)


def destru(c):
    st = stru.get(c, None)
    if st:
        return st[0]['font']
    return '\uFFFF'


def process(s):
    if isinstance(s, list):
        return [l for l in process('$'.join(s)).split('$') if re.match(r'[\u4E00-\u9FFF]', l)]

    s = re.sub(r'（.+）', '', s)
    s = re.sub(r'[\{\[].*?[\}\]]', lambda m: destru(m.group(0)), s)
    return convert(s, 'zh-cn')


def process2(s):
    if isinstance(s, list):
        return process2('$'.join(s)).split('$')

    s = re.sub(r'[\{\[].*?[\}\]]', lambda m: destru(m.group(0)), s)
    return convert(s, 'zh-cn')

# %%
import pandas as pd
import tqdm

for dn in tqdm.trange(0, 58):
    df = pd.read_json(f'chinese-poetry/json/poet.tang.{dn*1000}.json')
    df['paragraphs'] = df['paragraphs'].map(process)
    df['author'] = df['author'].map(process)
    df['title'] = df['title'].map(process)
    del df['tags']
    with open(f'data/poet.tang.{dn}.json', 'w', encoding='utf-8') as f:
        df.to_json(f, orient='records', force_ascii=False)
# Out:
# 100%|██████████| 58/58 [00:04<00:00, 11.79it/s]

# %%
import pandas as pd
from zhconv import convert

df = pd.read_json(f'chinese-poetry/json/authors.tang.json')
df['desc'] = df['desc'].map(process2)
df['name'] = df['name'].map(process2)
with open('data/authors.tang.json', 'w', encoding='utf-8') as f:
    df.to_json(f, orient='records', force_ascii=False)

# %% [markdown]
# 然后将清洗后的数据读入 DataFrame 中。

# %%
import pandas as pd
import functools

@functools.lru_cache()
def read_poem(n):
    df = pd.read_json(f'./data/poet.tang.{n}.json')

    def split(s):
        return s.replace('，', '。') \
            .replace('？', '。') \
            .replace('！', '。') \
            .strip('。').split('。')

    sens = []
    for poem in df['paragraphs']:
        sens.append(split(''.join(poem)))
    return sens


print(read_poem(0)[:1])
# Out:
# [['秦川雄帝宅', '函谷壮皇居', '绮殿千寻起', '离宫百雉余', '连甍遥接汉', '飞观迥凌虚', '云日隐层阙', '风烟出绮疏']]

# %% [markdown]
# 二、训练模型
#
# 采用 gensim 包提供的 FastText 模型，逐字训练 n-gram 向量。

# %%
import logging
from gensim.models.fasttext import FastText

model = FastText(min_count=1, iter=20, sg=1)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.WARNING)
# Out:
# 2021-10-30 16:15:21,238 : INFO : resetting layer weights

# %%
def train(n, update=False, save=False):
    sens = read_poem(n)
    model.build_vocab(sens, update=update)
    model.train(sens, total_examples=model.corpus_count, epochs=model.iter)
    if save:
        model.save("fasttext.model")

# %%
for dn in range(0, 58):
    train(dn, update=dn != 0, save=False)
    
model.save("fasttext.model")
# Out:
# 2021-10-30 16:15:39,978 : INFO : collecting all words and their counts
# 2021-10-30 16:15:40,702 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-10-30 16:15:40,705 : INFO : collected 8283 word types from a corpus of 8651 raw words and 1000 sentences
# 2021-10-30 16:15:40,706 : INFO : Loading a fresh vocabulary
# 2021-10-30 16:15:40,719 : INFO : effective_min_count=1 retains 8283 unique words (100% of original 8283, drops 0)
# 2021-10-30 16:15:40,719 : INFO : effective_min_count=1 leaves 8651 word corpus (100% of original 8651, drops 0)
# 2021-10-30 16:15:40,743 : INFO : deleting the raw counts dictionary of 8283 items
# 2021-10-30 16:15:40,743 : INFO : sample=0.001 downsamples 0 most-common words
# 2021-10-30 16:15:40,744 : INFO : downsampling leaves estimated 8651 word corpus (100.0% of prior 8651)
# 2021-10-30 16:15:40,810 : INFO : estimated required memory for 8283 words, 104374 buckets and 100 dimensions: 53799836 bytes
# 2021-10-30 16:15:40,814 : INFO : resetting layer weights
# C:\Users\wybxc\AppData\Local\Temp/ipykernel_20880/1326742963.py:4: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   model.train(sens, total_examples=model.corpus_count, epochs=model.iter)
# 2021-10-30 16:15:45,637 : INFO : training model with 3 workers on 8283 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2021-10-30 16:15:45,669 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:45,669 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:45,785 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:45,786 : INFO : EPOCH - 1 : training on 8651 raw words (8651 effective words) took 0.1s, 70202 effective words/s
# 2021-10-30 16:15:45,793 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:45,797 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:45,902 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:45,903 : INFO : EPOCH - 2 : training on 8651 raw words (8651 effective words) took 0.1s, 78903 effective words/s
# 2021-10-30 16:15:45,909 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:45,910 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:45,999 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,000 : INFO : EPOCH - 3 : training on 8651 raw words (8651 effective words) took 0.1s, 92414 effective words/s
# 2021-10-30 16:15:46,006 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,007 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,102 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,103 : INFO : EPOCH - 4 : training on 8651 raw words (8651 effective words) took 0.1s, 88844 effective words/s
# 2021-10-30 16:15:46,109 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,110 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,198 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,198 : INFO : EPOCH - 5 : training on 8651 raw words (8651 effective words) took 0.1s, 93804 effective words/s
# 2021-10-30 16:15:46,204 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,205 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,297 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,298 : INFO : EPOCH - 6 : training on 8651 raw words (8651 effective words) took 0.1s, 89635 effective words/s
# 2021-10-30 16:15:46,304 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,304 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,396 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,397 : INFO : EPOCH - 7 : training on 8651 raw words (8651 effective words) took 0.1s, 90674 effective words/s
# 2021-10-30 16:15:46,403 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,404 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,495 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,496 : INFO : EPOCH - 8 : training on 8651 raw words (8651 effective words) took 0.1s, 92400 effective words/s
# 2021-10-30 16:15:46,502 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,502 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,589 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,590 : INFO : EPOCH - 9 : training on 8651 raw words (8651 effective words) took 0.1s, 98450 effective words/s
# 2021-10-30 16:15:46,595 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,597 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,686 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,687 : INFO : EPOCH - 10 : training on 8651 raw words (8651 effective words) took 0.1s, 92162 effective words/s
# 2021-10-30 16:15:46,693 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,693 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,784 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,784 : INFO : EPOCH - 11 : training on 8651 raw words (8651 effective words) took 0.1s, 91542 effective words/s
# 2021-10-30 16:15:46,790 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,791 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,883 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,884 : INFO : EPOCH - 12 : training on 8651 raw words (8651 effective words) took 0.1s, 92345 effective words/s
# 2021-10-30 16:15:46,890 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,891 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:46,990 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:46,990 : INFO : EPOCH - 13 : training on 8651 raw words (8651 effective words) took 0.1s, 83610 effective words/s
# 2021-10-30 16:15:46,997 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:46,998 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:47,091 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:47,092 : INFO : EPOCH - 14 : training on 8651 raw words (8651 effective words) took 0.1s, 88281 effective words/s
# 2021-10-30 16:15:47,099 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:47,100 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:47,188 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:47,189 : INFO : EPOCH - 15 : training on 8651 raw words (8651 effective words) took 0.1s, 92954 effective words/s
# 2021-10-30 16:15:47,195 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:47,196 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:47,281 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:47,282 : INFO : EPOCH - 16 : training on 8651 raw words (8651 effective words) took 0.1s, 98819 effective words/s
# 2021-10-30 16:15:47,288 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:47,289 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:47,374 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:47,375 : INFO : EPOCH - 17 : training on 8651 raw words (8651 effective words) took 0.1s, 96435 effective words/s
# 2021-10-30 16:15:47,381 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:47,382 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:47,468 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:47,468 : INFO : EPOCH - 18 : training on 8651 raw words (8651 effective words) took 0.1s, 96395 effective words/s
# 2021-10-30 16:15:47,475 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:47,476 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:47,563 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:47,563 : INFO : EPOCH - 19 : training on 8651 raw words (8651 effective words) took 0.1s, 97644 effective words/s
# 2021-10-30 16:15:47,569 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:47,570 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:47,692 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:47,693 : INFO : EPOCH - 20 : training on 8651 raw words (8651 effective words) took 0.1s, 69891 effective words/s
# 2021-10-30 16:15:47,693 : INFO : training on a 173020 raw words (173020 effective words) took 2.1s, 84205 effective words/s
# 2021-10-30 16:15:47,694 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2021-10-30 16:15:49,370 : INFO : collecting all words and their counts
# 2021-10-30 16:15:49,371 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-10-30 16:15:49,376 : INFO : collected 10040 word types from a corpus of 10107 raw words and 1000 sentences
# 2021-10-30 16:15:49,377 : INFO : Updating model with new vocabulary
# 2021-10-30 16:15:49,395 : INFO : New added 10040 unique words (50% of original 20080) and increased the count of 10040 pre-existing words (50% of original 20080)
# 2021-10-30 16:15:49,438 : INFO : deleting the raw counts dictionary of 10040 items
# 2021-10-30 16:15:49,439 : INFO : sample=0.001 downsamples 0 most-common words
# 2021-10-30 16:15:49,439 : INFO : downsampling leaves estimated 20214 word corpus (200.0% of prior 10107)
# 2021-10-30 16:15:49,593 : INFO : estimated required memory for 18297 words, 249484 buckets and 100 dimensions: 126689556 bytes
# 2021-10-30 16:15:49,602 : INFO : updating layer weights
# 2021-10-30 16:15:51,635 : INFO : training model with 3 workers on 18297 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2021-10-30 16:15:51,642 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:51,644 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:51,773 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:51,773 : INFO : EPOCH - 1 : training on 10107 raw words (10107 effective words) took 0.1s, 76768 effective words/s
# 2021-10-30 16:15:51,781 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:51,784 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:51,932 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:51,932 : INFO : EPOCH - 2 : training on 10107 raw words (10107 effective words) took 0.2s, 64968 effective words/s
# 2021-10-30 16:15:51,941 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:51,944 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:52,077 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:52,078 : INFO : EPOCH - 3 : training on 10107 raw words (10107 effective words) took 0.1s, 71341 effective words/s
# 2021-10-30 16:15:52,086 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:52,089 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:52,228 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:52,229 : INFO : EPOCH - 4 : training on 10107 raw words (10107 effective words) took 0.1s, 70687 effective words/s
# 2021-10-30 16:15:52,236 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:52,239 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:52,376 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:52,377 : INFO : EPOCH - 5 : training on 10107 raw words (10107 effective words) took 0.1s, 70146 effective words/s
# 2021-10-30 16:15:52,384 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:52,387 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:52,518 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:52,519 : INFO : EPOCH - 6 : training on 10107 raw words (10107 effective words) took 0.1s, 75239 effective words/s
# 2021-10-30 16:15:52,526 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:52,529 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:52,653 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:52,653 : INFO : EPOCH - 7 : training on 10107 raw words (10107 effective words) took 0.1s, 79180 effective words/s
# 2021-10-30 16:15:52,661 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:52,663 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:52,785 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:52,786 : INFO : EPOCH - 8 : training on 10107 raw words (10107 effective words) took 0.1s, 78120 effective words/s
# 2021-10-30 16:15:52,793 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:52,796 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:52,920 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:52,921 : INFO : EPOCH - 9 : training on 10107 raw words (10107 effective words) took 0.1s, 78693 effective words/s
# 2021-10-30 16:15:52,928 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:52,931 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:53,058 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:53,059 : INFO : EPOCH - 10 : training on 10107 raw words (10107 effective words) took 0.1s, 77128 effective words/s
# 2021-10-30 16:15:53,066 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:53,069 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:53,194 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:53,195 : INFO : EPOCH - 11 : training on 10107 raw words (10107 effective words) took 0.1s, 76297 effective words/s
# 2021-10-30 16:15:53,202 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:53,204 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:53,329 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:53,330 : INFO : EPOCH - 12 : training on 10107 raw words (10107 effective words) took 0.1s, 78682 effective words/s
# 2021-10-30 16:15:53,338 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:53,340 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:53,466 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:53,467 : INFO : EPOCH - 13 : training on 10107 raw words (10107 effective words) took 0.1s, 78043 effective words/s
# 2021-10-30 16:15:53,473 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:53,476 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:53,599 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:53,600 : INFO : EPOCH - 14 : training on 10107 raw words (10107 effective words) took 0.1s, 77843 effective words/s
# 2021-10-30 16:15:53,607 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:53,610 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:53,735 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:53,736 : INFO : EPOCH - 15 : training on 10107 raw words (10107 effective words) took 0.1s, 78464 effective words/s
# 2021-10-30 16:15:53,743 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:53,746 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:53,873 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:53,874 : INFO : EPOCH - 16 : training on 10107 raw words (10107 effective words) took 0.1s, 74785 effective words/s
# 2021-10-30 16:15:53,881 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:53,884 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:54,011 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:54,012 : INFO : EPOCH - 17 : training on 10107 raw words (10107 effective words) took 0.1s, 75344 effective words/s
# 2021-10-30 16:15:54,019 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:54,022 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:54,155 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:54,156 : INFO : EPOCH - 18 : training on 10107 raw words (10107 effective words) took 0.1s, 71890 effective words/s
# 2021-10-30 16:15:54,163 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:54,166 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:54,293 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:54,294 : INFO : EPOCH - 19 : training on 10107 raw words (10107 effective words) took 0.1s, 74950 effective words/s
# 2021-10-30 16:15:54,301 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:54,303 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:54,429 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:54,430 : INFO : EPOCH - 20 : training on 10107 raw words (10107 effective words) took 0.1s, 76023 effective words/s
# 2021-10-30 16:15:54,430 : INFO : training on a 202140 raw words (202140 effective words) took 2.8s, 72337 effective words/s
# 2021-10-30 16:15:55,605 : INFO : collecting all words and their counts
# 2021-10-30 16:15:55,605 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-10-30 16:15:55,610 : INFO : collected 8668 word types from a corpus of 8767 raw words and 1002 sentences
# 2021-10-30 16:15:55,611 : INFO : Updating model with new vocabulary
# 2021-10-30 16:15:55,627 : INFO : New added 8668 unique words (50% of original 17336) and increased the count of 8668 pre-existing words (50% of original 17336)
# 2021-10-30 16:15:55,665 : INFO : deleting the raw counts dictionary of 8668 items
# 2021-10-30 16:15:55,666 : INFO : sample=0.001 downsamples 0 most-common words
# 2021-10-30 16:15:55,667 : INFO : downsampling leaves estimated 17534 word corpus (200.0% of prior 8767)
# 2021-10-30 16:15:55,885 : INFO : estimated required memory for 26212 words, 345912 buckets and 100 dimensions: 176903136 bytes
# 2021-10-30 16:15:55,898 : INFO : updating layer weights
# 2021-10-30 16:15:57,745 : WARNING : Effective 'alpha' higher than previous training cycles
# 2021-10-30 16:15:57,746 : INFO : training model with 3 workers on 26212 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2021-10-30 16:15:57,752 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:57,753 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:57,861 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:57,862 : INFO : EPOCH - 1 : training on 8767 raw words (8767 effective words) took 0.1s, 77428 effective words/s
# 2021-10-30 16:15:57,869 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:57,869 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:57,975 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:57,975 : INFO : EPOCH - 2 : training on 8767 raw words (8767 effective words) took 0.1s, 81582 effective words/s
# 2021-10-30 16:15:57,982 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:57,983 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:58,089 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:58,090 : INFO : EPOCH - 3 : training on 8767 raw words (8767 effective words) took 0.1s, 78852 effective words/s
# 2021-10-30 16:15:58,096 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:58,097 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:58,204 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:58,205 : INFO : EPOCH - 4 : training on 8767 raw words (8767 effective words) took 0.1s, 80578 effective words/s
# 2021-10-30 16:15:58,212 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:58,213 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:58,320 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:58,321 : INFO : EPOCH - 5 : training on 8767 raw words (8767 effective words) took 0.1s, 77734 effective words/s
# 2021-10-30 16:15:58,328 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:58,329 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:58,440 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:58,440 : INFO : EPOCH - 6 : training on 8767 raw words (8767 effective words) took 0.1s, 75742 effective words/s
# 2021-10-30 16:15:58,447 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:58,448 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:58,553 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:58,554 : INFO : EPOCH - 7 : training on 8767 raw words (8767 effective words) took 0.1s, 79024 effective words/s
# 2021-10-30 16:15:58,561 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:58,562 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:58,668 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:58,669 : INFO : EPOCH - 8 : training on 8767 raw words (8767 effective words) took 0.1s, 78694 effective words/s
# 2021-10-30 16:15:58,676 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:58,677 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:58,784 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:58,784 : INFO : EPOCH - 9 : training on 8767 raw words (8767 effective words) took 0.1s, 78343 effective words/s
# 2021-10-30 16:15:58,791 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:58,793 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:58,899 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:58,900 : INFO : EPOCH - 10 : training on 8767 raw words (8767 effective words) took 0.1s, 78492 effective words/s
# 2021-10-30 16:15:58,906 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:58,907 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,014 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,015 : INFO : EPOCH - 11 : training on 8767 raw words (8767 effective words) took 0.1s, 80563 effective words/s
# 2021-10-30 16:15:59,022 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,022 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,142 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,142 : INFO : EPOCH - 12 : training on 8767 raw words (8767 effective words) took 0.1s, 70116 effective words/s
# 2021-10-30 16:15:59,149 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,151 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,261 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,261 : INFO : EPOCH - 13 : training on 8767 raw words (8767 effective words) took 0.1s, 75941 effective words/s
# 2021-10-30 16:15:59,269 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,270 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,376 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,377 : INFO : EPOCH - 14 : training on 8767 raw words (8767 effective words) took 0.1s, 81438 effective words/s
# 2021-10-30 16:15:59,384 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,385 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,491 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,492 : INFO : EPOCH - 15 : training on 8767 raw words (8767 effective words) took 0.1s, 80804 effective words/s
# 2021-10-30 16:15:59,499 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,499 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,606 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,606 : INFO : EPOCH - 16 : training on 8767 raw words (8767 effective words) took 0.1s, 80852 effective words/s
# 2021-10-30 16:15:59,613 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,614 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,725 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,725 : INFO : EPOCH - 17 : training on 8767 raw words (8767 effective words) took 0.1s, 75674 effective words/s
# 2021-10-30 16:15:59,732 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,732 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,838 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,838 : INFO : EPOCH - 18 : training on 8767 raw words (8767 effective words) took 0.1s, 82294 effective words/s
# 2021-10-30 16:15:59,869 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,870 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:15:59,976 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:15:59,977 : INFO : EPOCH - 19 : training on 8767 raw words (8767 effective words) took 0.1s, 81205 effective words/s
# 2021-10-30 16:15:59,984 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:15:59,985 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:00,090 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:00,090 : INFO : EPOCH - 20 : training on 8767 raw words (8767 effective words) took 0.1s, 82467 effective words/s
# 2021-10-30 16:16:00,091 : INFO : training on a 175340 raw words (175340 effective words) took 2.3s, 74770 effective words/s
# 2021-10-30 16:16:00,092 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2021-10-30 16:16:01,216 : INFO : collecting all words and their counts
# 2021-10-30 16:16:01,217 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-10-30 16:16:01,221 : INFO : collected 10322 word types from a corpus of 10432 raw words and 1001 sentences
# 2021-10-30 16:16:01,222 : INFO : Updating model with new vocabulary
# 2021-10-30 16:16:01,239 : INFO : New added 10322 unique words (50% of original 20644) and increased the count of 10322 pre-existing words (50% of original 20644)
# 2021-10-30 16:16:01,288 : INFO : deleting the raw counts dictionary of 10322 items
# 2021-10-30 16:16:01,289 : INFO : sample=0.001 downsamples 0 most-common words
# 2021-10-30 16:16:01,289 : INFO : downsampling leaves estimated 20864 word corpus (200.0% of prior 10432)
# 2021-10-30 16:16:01,621 : INFO : estimated required memory for 36005 words, 452296 buckets and 100 dimensions: 233807124 bytes
# 2021-10-30 16:16:01,638 : INFO : updating layer weights
# 2021-10-30 16:16:04,095 : WARNING : Effective 'alpha' higher than previous training cycles
# 2021-10-30 16:16:04,095 : INFO : training model with 3 workers on 36005 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2021-10-30 16:16:04,103 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:04,113 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:04,280 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:04,281 : INFO : EPOCH - 1 : training on 10432 raw words (10432 effective words) took 0.2s, 57190 effective words/s
# 2021-10-30 16:16:04,290 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:04,296 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:04,424 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:04,424 : INFO : EPOCH - 2 : training on 10432 raw words (10432 effective words) took 0.1s, 74428 effective words/s
# 2021-10-30 16:16:04,432 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:04,440 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:04,577 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:04,578 : INFO : EPOCH - 3 : training on 10432 raw words (10432 effective words) took 0.2s, 69496 effective words/s
# 2021-10-30 16:16:04,586 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:04,592 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:04,721 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:04,721 : INFO : EPOCH - 4 : training on 10432 raw words (10432 effective words) took 0.1s, 76453 effective words/s
# 2021-10-30 16:16:04,729 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:04,736 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:04,863 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:04,864 : INFO : EPOCH - 5 : training on 10432 raw words (10432 effective words) took 0.1s, 77357 effective words/s
# 2021-10-30 16:16:04,871 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:04,878 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:05,013 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:05,013 : INFO : EPOCH - 6 : training on 10432 raw words (10432 effective words) took 0.1s, 73265 effective words/s
# 2021-10-30 16:16:05,021 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:05,029 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:05,153 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:05,153 : INFO : EPOCH - 7 : training on 10432 raw words (10432 effective words) took 0.1s, 78804 effective words/s
# 2021-10-30 16:16:05,160 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:05,168 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:05,288 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:05,289 : INFO : EPOCH - 8 : training on 10432 raw words (10432 effective words) took 0.1s, 81010 effective words/s
# 2021-10-30 16:16:05,296 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:05,303 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:05,496 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:05,497 : INFO : EPOCH - 9 : training on 10432 raw words (10432 effective words) took 0.2s, 51706 effective words/s
# 2021-10-30 16:16:05,505 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:05,512 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:05,642 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:05,643 : INFO : EPOCH - 10 : training on 10432 raw words (10432 effective words) took 0.1s, 73309 effective words/s
# 2021-10-30 16:16:05,650 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:05,657 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:05,782 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:05,783 : INFO : EPOCH - 11 : training on 10432 raw words (10432 effective words) took 0.1s, 76464 effective words/s
# 2021-10-30 16:16:05,790 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:05,797 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:05,922 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:05,923 : INFO : EPOCH - 12 : training on 10432 raw words (10432 effective words) took 0.1s, 76110 effective words/s
# 2021-10-30 16:16:05,930 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:05,937 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:06,061 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:06,061 : INFO : EPOCH - 13 : training on 10432 raw words (10432 effective words) took 0.1s, 77062 effective words/s
# 2021-10-30 16:16:06,070 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:06,076 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:06,201 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:06,202 : INFO : EPOCH - 14 : training on 10432 raw words (10432 effective words) took 0.1s, 76022 effective words/s
# 2021-10-30 16:16:06,209 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:06,217 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:06,344 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:06,345 : INFO : EPOCH - 15 : training on 10432 raw words (10432 effective words) took 0.1s, 76946 effective words/s
# 2021-10-30 16:16:06,352 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:06,359 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:06,492 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:06,493 : INFO : EPOCH - 16 : training on 10432 raw words (10432 effective words) took 0.1s, 74318 effective words/s
# 2021-10-30 16:16:06,500 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:06,507 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:06,632 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:06,633 : INFO : EPOCH - 17 : training on 10432 raw words (10432 effective words) took 0.1s, 78450 effective words/s
# 2021-10-30 16:16:06,640 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:06,647 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:06,773 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:06,774 : INFO : EPOCH - 18 : training on 10432 raw words (10432 effective words) took 0.1s, 77547 effective words/s
# 2021-10-30 16:16:06,782 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:06,789 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:06,917 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:06,918 : INFO : EPOCH - 19 : training on 10432 raw words (10432 effective words) took 0.1s, 76032 effective words/s
# 2021-10-30 16:16:06,925 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:06,932 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:07,057 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:07,058 : INFO : EPOCH - 20 : training on 10432 raw words (10432 effective words) took 0.1s, 76041 effective words/s
# 2021-10-30 16:16:07,059 : INFO : training on a 208640 raw words (208640 effective words) took 3.0s, 70407 effective words/s
# 2021-10-30 16:16:08,875 : INFO : collecting all words and their counts
# 2021-10-30 16:16:08,875 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-10-30 16:16:08,879 : INFO : collected 11495 word types from a corpus of 11518 raw words and 1000 sentences
# 2021-10-30 16:16:08,879 : INFO : Updating model with new vocabulary
# 2021-10-30 16:16:08,900 : INFO : New added 11495 unique words (50% of original 22990) and increased the count of 11495 pre-existing words (50% of original 22990)
# 2021-10-30 16:16:08,946 : INFO : deleting the raw counts dictionary of 11495 items
# 2021-10-30 16:16:08,947 : INFO : sample=0.001 downsamples 0 most-common words
# 2021-10-30 16:16:08,948 : INFO : downsampling leaves estimated 23036 word corpus (200.0% of prior 11518)
# 2021-10-30 16:16:09,342 : INFO : estimated required memory for 46419 words, 558863 buckets and 100 dimensions: 291725332 bytes
# 2021-10-30 16:16:09,364 : INFO : updating layer weights
# 2021-10-30 16:16:11,977 : WARNING : Effective 'alpha' higher than previous training cycles
# 2021-10-30 16:16:11,977 : INFO : training model with 3 workers on 46419 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2021-10-30 16:16:11,985 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:12,010 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:12,123 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:12,123 : INFO : EPOCH - 1 : training on 11518 raw words (11518 effective words) took 0.1s, 81041 effective words/s
# 2021-10-30 16:16:12,130 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:12,158 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:12,271 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:12,272 : INFO : EPOCH - 2 : training on 11518 raw words (11518 effective words) took 0.1s, 81167 effective words/s
# 2021-10-30 16:16:12,280 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:12,305 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:12,419 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:12,420 : INFO : EPOCH - 3 : training on 11518 raw words (11518 effective words) took 0.1s, 79603 effective words/s
# 2021-10-30 16:16:12,428 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:12,451 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:12,563 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:12,564 : INFO : EPOCH - 4 : training on 11518 raw words (11518 effective words) took 0.1s, 84182 effective words/s
# 2021-10-30 16:16:12,571 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:12,595 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:12,707 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:12,708 : INFO : EPOCH - 5 : training on 11518 raw words (11518 effective words) took 0.1s, 84216 effective words/s
# 2021-10-30 16:16:12,715 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:12,739 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:12,850 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:12,850 : INFO : EPOCH - 6 : training on 11518 raw words (11518 effective words) took 0.1s, 82868 effective words/s
# 2021-10-30 16:16:12,858 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:12,882 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:12,995 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:12,996 : INFO : EPOCH - 7 : training on 11518 raw words (11518 effective words) took 0.1s, 83559 effective words/s
# 2021-10-30 16:16:13,003 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:13,026 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:13,138 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:13,139 : INFO : EPOCH - 8 : training on 11518 raw words (11518 effective words) took 0.1s, 82194 effective words/s
# 2021-10-30 16:16:13,147 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:13,175 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:13,285 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:13,286 : INFO : EPOCH - 9 : training on 11518 raw words (11518 effective words) took 0.1s, 80279 effective words/s
# 2021-10-30 16:16:13,294 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:13,321 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:13,435 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:13,435 : INFO : EPOCH - 10 : training on 11518 raw words (11518 effective words) took 0.1s, 80840 effective words/s
# 2021-10-30 16:16:13,443 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:13,466 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:13,581 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:13,582 : INFO : EPOCH - 11 : training on 11518 raw words (11518 effective words) took 0.1s, 80428 effective words/s
# 2021-10-30 16:16:13,590 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:13,614 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:13,745 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:13,745 : INFO : EPOCH - 12 : training on 11518 raw words (11518 effective words) took 0.2s, 71568 effective words/s
# 2021-10-30 16:16:13,753 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:13,780 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:13,898 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:13,899 : INFO : EPOCH - 13 : training on 11518 raw words (11518 effective words) took 0.2s, 76711 effective words/s
# 2021-10-30 16:16:13,906 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:13,929 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:14,040 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:14,041 : INFO : EPOCH - 14 : training on 11518 raw words (11518 effective words) took 0.1s, 85112 effective words/s
# 2021-10-30 16:16:14,048 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:14,075 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:14,185 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:14,186 : INFO : EPOCH - 15 : training on 11518 raw words (11518 effective words) took 0.1s, 83418 effective words/s
# 2021-10-30 16:16:14,194 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:14,216 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:14,329 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:14,330 : INFO : EPOCH - 16 : training on 11518 raw words (11518 effective words) took 0.1s, 84101 effective words/s
# 2021-10-30 16:16:14,337 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:14,361 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:14,493 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:14,494 : INFO : EPOCH - 17 : training on 11518 raw words (11518 effective words) took 0.2s, 73286 effective words/s
# 2021-10-30 16:16:14,507 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:14,549 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:14,672 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:14,672 : INFO : EPOCH - 18 : training on 11518 raw words (11518 effective words) took 0.2s, 67553 effective words/s
# 2021-10-30 16:16:14,680 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:14,704 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:14,833 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:14,834 : INFO : EPOCH - 19 : training on 11518 raw words (11518 effective words) took 0.2s, 72482 effective words/s
# 2021-10-30 16:16:14,841 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:16:14,866 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:16:14,991 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:16:14,991 : INFO : EPOCH - 20 : training on 11518 raw words (11518 effective words) took 0.2s, 74625 effective words/s
# 2021-10-30 16:16:14,992 : INFO : training on a 230360 raw words (230360 effective words) took 3.0s, 76423 effective words/s
# 2021-10-30 16:16:16,709 : INFO : collecting all words and their counts
# 2021-10-30 16:16:16,710 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-10-30 16:16:16,715 : INFO : collected 10528 word types from a corpus of 10629 raw words and 1000 sentences
# 2021-10-30 16:16:16,716 : INFO : Updating model with new vocabulary
# 2021-10-30 16:16:16,794 : INFO : New added 10528 unique words (50% of original 21056) and increased the count of 10528 pre-existing words (50% of original 21056)
# ...
# 2021-10-30 16:36:14,862 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:14,863 : INFO : EPOCH - 8 : training on 6034 raw words (6034 effective words) took 0.1s, 51865 effective words/s
# 2021-10-30 16:36:14,869 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:14,870 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:14,965 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:14,965 : INFO : EPOCH - 9 : training on 6034 raw words (6034 effective words) took 0.1s, 60412 effective words/s
# 2021-10-30 16:36:14,972 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:14,974 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,091 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,092 : INFO : EPOCH - 10 : training on 6034 raw words (6034 effective words) took 0.1s, 50530 effective words/s
# 2021-10-30 16:36:15,099 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,100 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,190 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,190 : INFO : EPOCH - 11 : training on 6034 raw words (6034 effective words) took 0.1s, 65668 effective words/s
# 2021-10-30 16:36:15,197 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,199 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,314 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,315 : INFO : EPOCH - 12 : training on 6034 raw words (6034 effective words) took 0.1s, 49965 effective words/s
# 2021-10-30 16:36:15,323 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,324 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,413 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,414 : INFO : EPOCH - 13 : training on 6034 raw words (6034 effective words) took 0.1s, 63420 effective words/s
# 2021-10-30 16:36:15,422 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,422 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,545 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,545 : INFO : EPOCH - 14 : training on 6034 raw words (6034 effective words) took 0.1s, 47272 effective words/s
# 2021-10-30 16:36:15,552 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,553 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,638 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,638 : INFO : EPOCH - 15 : training on 6034 raw words (6034 effective words) took 0.1s, 67247 effective words/s
# 2021-10-30 16:36:15,645 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,647 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,764 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,765 : INFO : EPOCH - 16 : training on 6034 raw words (6034 effective words) took 0.1s, 48804 effective words/s
# 2021-10-30 16:36:15,771 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,772 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,858 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,859 : INFO : EPOCH - 17 : training on 6034 raw words (6034 effective words) took 0.1s, 66332 effective words/s
# 2021-10-30 16:36:15,871 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,872 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:15,983 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:15,984 : INFO : EPOCH - 18 : training on 6034 raw words (6034 effective words) took 0.1s, 53048 effective words/s
# 2021-10-30 16:36:15,991 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:15,991 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:16,112 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:16,113 : INFO : EPOCH - 19 : training on 6034 raw words (6034 effective words) took 0.1s, 47838 effective words/s
# 2021-10-30 16:36:16,122 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:16,123 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:16,214 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:16,215 : INFO : EPOCH - 20 : training on 6034 raw words (6034 effective words) took 0.1s, 61571 effective words/s
# 2021-10-30 16:36:16,216 : INFO : training on a 120680 raw words (120680 effective words) took 2.3s, 52831 effective words/s
# 2021-10-30 16:36:16,216 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2021-10-30 16:36:32,493 : INFO : collecting all words and their counts
# 2021-10-30 16:36:32,494 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-10-30 16:36:32,496 : INFO : collected 3464 word types from a corpus of 3533 raw words and 591 sentences
# 2021-10-30 16:36:32,496 : INFO : Updating model with new vocabulary
# 2021-10-30 16:36:32,503 : INFO : New added 3464 unique words (50% of original 6928) and increased the count of 3464 pre-existing words (50% of original 6928)
# 2021-10-30 16:36:32,519 : INFO : deleting the raw counts dictionary of 3464 items
# 2021-10-30 16:36:32,520 : INFO : sample=0.001 downsamples 6 most-common words
# 2021-10-30 16:36:32,521 : INFO : downsampling leaves estimated 7040 word corpus (199.3% of prior 3533)
# 2021-10-30 16:36:37,496 : INFO : estimated required memory for 485165 words, 1936953 buckets and 100 dimensions: 1492457788 bytes
# 2021-10-30 16:36:37,579 : INFO : updating layer weights
# 2021-10-30 16:36:48,163 : WARNING : Effective 'alpha' higher than previous training cycles
# 2021-10-30 16:36:48,164 : INFO : training model with 3 workers on 485165 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2021-10-30 16:36:48,169 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,170 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,227 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,228 : INFO : EPOCH - 1 : training on 3533 raw words (3519 effective words) took 0.1s, 57488 effective words/s
# 2021-10-30 16:36:48,233 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,234 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,317 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,318 : INFO : EPOCH - 2 : training on 3533 raw words (3517 effective words) took 0.1s, 40199 effective words/s
# 2021-10-30 16:36:48,326 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,328 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,403 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,404 : INFO : EPOCH - 3 : training on 3533 raw words (3514 effective words) took 0.1s, 43080 effective words/s
# 2021-10-30 16:36:48,410 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,411 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,483 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,484 : INFO : EPOCH - 4 : training on 3533 raw words (3523 effective words) took 0.1s, 45707 effective words/s
# 2021-10-30 16:36:48,490 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,490 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,546 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,547 : INFO : EPOCH - 5 : training on 3533 raw words (3519 effective words) took 0.1s, 59271 effective words/s
# 2021-10-30 16:36:48,553 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,553 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,618 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,619 : INFO : EPOCH - 6 : training on 3533 raw words (3520 effective words) took 0.1s, 50917 effective words/s
# 2021-10-30 16:36:48,625 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,626 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,716 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,717 : INFO : EPOCH - 7 : training on 3533 raw words (3523 effective words) took 0.1s, 37252 effective words/s
# 2021-10-30 16:36:48,723 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,724 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,793 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,794 : INFO : EPOCH - 8 : training on 3533 raw words (3518 effective words) took 0.1s, 47844 effective words/s
# 2021-10-30 16:36:48,801 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,802 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,862 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,863 : INFO : EPOCH - 9 : training on 3533 raw words (3521 effective words) took 0.1s, 57459 effective words/s
# 2021-10-30 16:36:48,868 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,869 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,928 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,928 : INFO : EPOCH - 10 : training on 3533 raw words (3520 effective words) took 0.1s, 55958 effective words/s
# 2021-10-30 16:36:48,934 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:48,934 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:48,994 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:48,994 : INFO : EPOCH - 11 : training on 3533 raw words (3515 effective words) took 0.1s, 55703 effective words/s
# 2021-10-30 16:36:49,000 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,001 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,091 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,092 : INFO : EPOCH - 12 : training on 3533 raw words (3522 effective words) took 0.1s, 38396 effective words/s
# 2021-10-30 16:36:49,100 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,101 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,170 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,171 : INFO : EPOCH - 13 : training on 3533 raw words (3518 effective words) took 0.1s, 47216 effective words/s
# 2021-10-30 16:36:49,177 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,178 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,246 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,247 : INFO : EPOCH - 14 : training on 3533 raw words (3522 effective words) took 0.1s, 50119 effective words/s
# 2021-10-30 16:36:49,254 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,255 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,327 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,328 : INFO : EPOCH - 15 : training on 3533 raw words (3521 effective words) took 0.1s, 45338 effective words/s
# 2021-10-30 16:36:49,333 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,334 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,415 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,416 : INFO : EPOCH - 16 : training on 3533 raw words (3517 effective words) took 0.1s, 41269 effective words/s
# 2021-10-30 16:36:49,425 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,425 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,499 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,500 : INFO : EPOCH - 17 : training on 3533 raw words (3524 effective words) took 0.1s, 44201 effective words/s
# 2021-10-30 16:36:49,506 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,507 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,575 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,576 : INFO : EPOCH - 18 : training on 3533 raw words (3519 effective words) took 0.1s, 48232 effective words/s
# 2021-10-30 16:36:49,581 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,582 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,655 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,655 : INFO : EPOCH - 19 : training on 3533 raw words (3518 effective words) took 0.1s, 45904 effective words/s
# 2021-10-30 16:36:49,661 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 16:36:49,661 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 16:36:49,725 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 16:36:49,726 : INFO : EPOCH - 20 : training on 3533 raw words (3522 effective words) took 0.1s, 52279 effective words/s
# 2021-10-30 16:36:49,726 : INFO : training on a 70660 raw words (70392 effective words) took 1.6s, 45031 effective words/s
# 2021-10-30 16:36:49,728 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2021-10-30 16:37:08,746 : INFO : saving FastText object under fasttext.model, separately None
# 2021-10-30 16:37:08,747 : INFO : storing np array 'vectors' to fasttext.model.wv.vectors.npy
# 2021-10-30 16:37:12,121 : INFO : storing np array 'vectors_vocab' to fasttext.model.wv.vectors_vocab.npy
# 2021-10-30 16:37:18,029 : INFO : storing np array 'vectors_ngrams' to fasttext.model.wv.vectors_ngrams.npy
# 2021-10-30 16:37:28,573 : INFO : not storing attribute vectors_norm
# 2021-10-30 16:37:28,574 : INFO : not storing attribute vectors_vocab_norm
# 2021-10-30 16:37:28,574 : INFO : not storing attribute vectors_ngrams_norm
# 2021-10-30 16:37:28,575 : INFO : not storing attribute buckets_word
# 2021-10-30 16:37:28,575 : INFO : storing np array 'syn1neg' to fasttext.model.trainables.syn1neg.npy
# 2021-10-30 16:37:31,133 : INFO : storing np array 'vectors_vocab_lockf' to fasttext.model.trainables.vectors_vocab_lockf.npy
# 2021-10-30 16:37:36,308 : INFO : storing np array 'vectors_ngrams_lockf' to fasttext.model.trainables.vectors_ngrams_lockf.npy
# 2021-10-30 16:37:48,099 : INFO : saved fasttext.model

# %% [markdown]
# 训练完成后，可以直接从本地加载训练过的模型。

# %%
from gensim.models.fasttext import FastText
model = FastText.load('fasttext.model')

# %% [markdown]
# 三、生成词表
#
# 利用 FastText 的训练结果，生成古诗的词表。

# %% [markdown]
# 首先，生成所有的2到4字的相邻字符组合，并统计词频。

# %%
from collections import Counter

words_counter = Counter()


def update_counter(words_counter, dn):
    for n in range(2, 5):
        words_counter.update(
            ''.join(wd_t) for sen in read_poem(dn) for s in sen
            for wd_t in zip(*(s[i:] for i in range(n)))
        )
    return words_counter

# %%
words_counter = update_counter(Counter(), 0)

words, counts = zip(*words_counter.most_common())
print(words[:10])
# Out:
# ('万国', '肃肃', '神其', '天地', '四海', '将军', '万里', '明德', '无疆', '万方')

# %%
import tqdm

words_counter = Counter()
for dn in tqdm.trange(0, 58):
    update_counter(words_counter, dn)

words, counts = zip(*words_counter.most_common())
print(len(words))
print(words[:10])
# Out:
# 100%|██████████| 58/58 [00:12<00:00,  4.50it/s]
# 3442366
# ('何处', '不知', '万里', '千里', '不见', '白云', '今日', '不可', '春风', '不得')

# %% [markdown]
# 计算词评分:
#
# $$\mathrm{Score}_{w} = || \mathrm{Vec}_w || \times \ln (D_w+1)$$
#
# 其中$\mathrm{Vec}_w$是 FastText 计算出的平均词向量，$D_w$是词频。

# %%
import numpy as np

MIN_SCORE = 15.0

counts = np.array(counts) + 1
scores = np.linalg.norm(model.wv[words], axis=1) * np.log(counts)
freq_words_index = np.nonzero(scores > MIN_SCORE)[0]
freq_words = [words[i] for i in freq_words_index]
print(len(freq_words))
print(freq_words[:10])
print(scores[freq_words_index][:10])
# Out:
# 34644
# ['何处', '不知', '万里', '千里', '不见', '白云', '今日', '不可', '春风', '不得']
# [139.97656432 150.45272063 181.19890067 188.48421925 180.35110888
#  191.70653118 162.29948331  69.08332987 173.11758386 169.24598314]

# %% [markdown]
# 在利用词评分分词的时候，遇到了词的一部分的评分低于整体评分，导致分词结果带有冗余成分的问题。
#
# 因此，对初步分词的结果进行细化，比如将“人何处”分成“人”和“何处”，对于成为其他词一部分的词，降低选取标准。

# %%
freq_words_sub = set()
for n in range(2, 5):
    freq_words_sub.update(
        ''.join(wd_t) for wd in freq_words
        for wd_t in zip(*(wd[i:] for i in range(n)))
    )
print(list(freq_words_sub)[:10])
# Out:
# ['平生官', '今春', '有时帘', '日骑', '首暮', '万里从', '道国', '至今听', '回首陇', '日夕白']

# %%
import tqdm

true_words = set()
for wd in tqdm.tqdm(
    sorted(freq_words_sub, key=lambda w: words_counter[w], reverse=True)
):
    if all(wd_p not in wd for wd_p in true_words) and \
        np.linalg.norm(model.wv[wd]) * np.log(words_counter[wd] + 1) > MIN_SCORE / 3:
        true_words.add(wd)
true_words = list(true_words)
# Out:
# 100%|██████████| 50134/50134 [00:53<00:00, 932.42it/s]

# %%
true_counts = np.array([words_counter[wd] for wd in true_words])
true_scores = np.linalg.norm(model.wv[true_words], axis=1) * np.log(true_counts)
freq_t_words_index = np.nonzero(true_scores > MIN_SCORE)[0]
print([words[i] for i in freq_t_words_index[:10]])
# Out:
# ['万里', '今日', '不可', '春风', '不得', '明月', '风吹', '惆怅', '故人', '秋风']

# %%
with open('words.txt', 'w', encoding='utf-8') as f:
    for i in sorted(freq_t_words_index, key=lambda i: -true_scores[i]):
        f.write(f'{true_words[i]} {true_scores[i]}\n')

# %% [markdown]
# 最后统计一下单字的结果，按照单字在词表中的词频排序。

# %%
character_counter = Counter()
for i in freq_t_words_index:
    character_counter.update(true_words[i])

with open('characters.txt', 'w', encoding='utf-8') as f:
    for c, cnt in character_counter.most_common():
        f.write(f'{c} {cnt}\n')

# %% [markdown]
# 三、挖掘近义词关系

# %% [markdown]
# 首先，将词表中的词和所有的单字读入。

# %%
wds = []

with open('words.txt', 'r', encoding='utf-8') as f:
    wds += [line.split()[0] for line in f]

with open('characters.txt', 'r', encoding='utf-8') as f:
    wds += [line.split()[0] for line in f]

print(wds[:10])
# Out:
# ['白云', '千里', '万里', '不见', '春风', '不得', '故人', '悠悠', '今日', '十年']

# %% [markdown]
# 建立共现网络，判断连接情况相似的词为近义词。
#
# 此处认为在同一首诗中出现即为共现。

# %%
import tqdm
import itertools
import numpy as np

wds_inv = {wd: index for index, wd in enumerate(wds)}

coo = np.zeros((len(wds), len(wds)), dtype=int)
for n in tqdm.trange(0, 58):
    for lines in read_poem(n):
        line = '。'.join(lines)
        near_wds = {
            wds_inv[wd]
            for wd in itertools.
            chain((''.join(wd_t) for wd_t in zip(line, line[1:])), line)
            if wd in wds_inv
        }
        for i, j in itertools.product(near_wds, near_wds):
            coo[i, j] += 1
# Out:
# 100%|██████████| 58/58 [02:21<00:00,  2.44s/it]

# %% [markdown]
# 构建共现网络，有共现关系的设置边权为1，否则为0。

# %%
weights = np.zeros(coo.shape)
np.place(weights, coo > 0, 1)

# %% [markdown]
# 对共现矩阵进行 PCA 降维，得到基于共现关系的词向量$\mathrm{v}_w$。

# %%
from sklearn.decomposition import PCA

vectors_coo = PCA(n_components=200).fit_transform(weights)
vectors_coo /= np.linalg.norm(vectors_coo, axis=1)[:, np.newaxis]
connection_coo = vectors_coo @ vectors_coo.T

# %%
import pandas as pd

i, j = 15, 10
pd.DataFrame(connection_coo[:i, :j], index=wds[:i], columns=wds[:j])
# Out:
#           白云        千里        万里        不见        春风        不得        故人  \
# 白云  1.000000  0.936267  0.925546  0.920675  0.885184  0.897835  0.887579
# 千里  0.936267  1.000000  0.978596  0.956124  0.915435  0.936532  0.915425
# 万里  0.925546  0.978596  1.000000  0.961704  0.911911  0.938451  0.905343
# 不见  0.920675  0.956124  0.961704  1.000000  0.926425  0.956222  0.876557
# 春风  0.885184  0.915435  0.911911  0.926425  1.000000  0.900608  0.881940
# 不得  0.897835  0.936532  0.938451  0.956222  0.900608  1.000000  0.863441
# 故人  0.887579  0.915425  0.905343  0.876557  0.881940  0.863441  1.000000
# 悠悠  0.903412  0.916342  0.916629  0.919297  0.885647  0.908748  0.898188
# 今日  0.910064  0.950373  0.953293  0.960588  0.923731  0.940294  0.892803
# 十年  0.879519  0.923391  0.918560  0.914188  0.868277  0.920743  0.876716
# 白日  0.900675  0.931978  0.930300  0.935680  0.888343  0.930918  0.876960
# 天子  0.827652  0.882760  0.889212  0.897047  0.840558  0.907851  0.817728
# 主人  0.824781  0.870137  0.856136  0.871208  0.858574  0.885618  0.848266
# 长安  0.858126  0.904973  0.904741  0.913848  0.910373  0.904106  0.883155
# 不知  0.935260  0.956714  0.953736  0.970947  0.925664  0.959729  0.880943
#
#           悠悠        今日        十年
# 白云  0.903412  0.910064  0.879519
# 千里  0.916342  0.950373  0.923391
# 万里  0.916629  0.953293  0.918560
# 不见  0.919297  0.960588  0.914188
# 春风  0.885647  0.923731  0.868277
# 不得  0.908748  0.940294  0.920743
# 故人  0.898188  0.892803  0.876716
# 悠悠  1.000000  0.913650  0.883448
# 今日  0.913650  1.000000  0.925300
# 十年  0.883448  0.925300  1.000000
# 白日  0.908365  0.925151  0.910065
# 天子  0.848095  0.888960  0.870162
# 主人  0.848922  0.874267  0.868273
# 长安  0.873935  0.915000  0.901228
# 不知  0.913411  0.960113  0.914945

# %%
def most_similar(wd, connection, n=10):
    k = wds.index(wd)
    topn_index = np.argpartition(-connection[k], n)[:n]
    return sorted(
        [(wds[i], connection[k, i]) for i in topn_index], key=lambda x: -x[1]
    )

# %%
most_similar('桃李', connection_coo, n=10)
# Out:
# [('桃李', 0.9999999999999993),
#  ('李', 0.7682370575452178),
#  ('春风', 0.7661175648578242),
#  ('可怜', 0.7475218440438887),
#  ('美人', 0.7457272028695293),
#  ('扇', 0.7450352150092245),
#  ('长安', 0.7441540048791975),
#  ('黄金', 0.7429098172530839),
#  ('年年', 0.7424770348500368),
#  ('帐', 0.741735314433345)]

# %% [markdown]
# 四、建立近义词数据库
#
# 按照共现矩阵，将与每个词最接近的10个词认定为近义词，写入到数据库中。

# %%
import yaml
import py2neo

with open('../cipher.yml', 'r', encoding='utf-8') as f:
    cipher = yaml.safe_load(f)

graph = py2neo.Graph(cipher['url'], auth=("neo4j", cipher['passwd']))

# %%
graph.run("CREATE INDEX IF NOT EXISTS FOR (w:Word) ON (w.name)")
# Out:
# (No data)

# %%
import tqdm
from py2neo.bulk import merge_nodes
from itertools import islice

batch_size = 1000
stream = ((wd, ) for wd in wds)
for _ in tqdm.trange(len(wds) // batch_size + 1):
    batch = islice(stream, batch_size)
    if batch:
        merge_nodes(
            graph.auto(),
            batch, ('Word', 'name'),
            labels=('Word', ),
            keys=('name', )
        )
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 15.80it/s]

# %%
import tqdm
import numpy as np
from py2neo.bulk import merge_relationships
from itertools import islice

K = 10
rels = []
for i, wd in enumerate(tqdm.tqdm(wds)):
    topk = np.argpartition(-connection_coo[i], K)[:K]
    for j in topk:
        if i != j:
            rels.append((wd, (float(connection_coo[i, j]), ), wds[j]))

stream = iter(rels)
batch_size = 1000

for _ in tqdm.trange(len(rels) // batch_size + 1):
    batch = islice(stream, batch_size)
    if batch:
        merge_relationships(
            graph.auto(),
            batch,
            'SIMILAR',
            start_node_key=('Word', 'name'),
            end_node_key=('Word', 'name'),
            keys=['weight']
        )
# Out:
# 100%|██████████| 11745/11745 [00:01<00:00, 8492.92it/s]
# 100%|██████████| 106/106 [00:05<00:00, 18.39it/s]

# %% [markdown]
# 近义词读取示例：

# %%
node = graph.nodes.match('Word', name='千里').first()
if node:
    sims = graph.relationships.match((node, None), r_type='SIMILAR').all()
    for sim in sims:
        print(sim.end_node['name'], sim['weight'])
# Out:
# 沙 0.9791039912825853
# 州 0.9775936852298319
# 亭 0.9776948234877295
# 征 0.9809392490464931
# 吴 0.9810284176635078
# 川 0.9791498953812668
# 楚 0.9801299473151225
# 陵 0.9796371665953145
# 秦 0.9782973471070116

# %% [markdown]
# 利用束搜索拓宽近义词范围。

# %%
def similar_words(wd, depth=3, width=10):
    beam = [(graph.nodes.match('Word', name=wd).first(), 1.0)]
    if not beam[0][0]:
        return []
    for _ in range(depth):
        possibility = beam.copy()
        selected = {node['name'] for node, _ in beam}
        for node, score in beam:
            sims = graph.relationships.match((node, None),
                                             r_type='SIMILAR').all()
            for sim in sims:
                if sim.end_node['name'] not in selected:
                    selected.add(sim.end_node['name'])
                    possibility.append((sim.end_node, score * sim['weight']))
        possibility.sort(key=lambda x: -x[1])
        beam = possibility[:width]

    return [(node['name'], score) for node, score in beam]

# %% [markdown]
# 对于未登录词，考虑将词语拆分，获取每一部分的近义词，构建并集，奖励交集。

# %%
def similar_words_plus(wd, depth=3, width=10):
    beam = [
        (
            wd_t, graph.nodes.match('Word',
                                    name=wd_t).first(), len(wd_t) / len(wd)
        )
        for wd_t in [''.join(wd_t) for wd_t in zip(*(wd, wd[1:]))] + list(wd)
    ]
    beam = [(w, n, s) for w, n, s in beam if n]
    if not beam:
        return []
    for _ in range(depth):
        possibility = {wd: (wd, node, score) for wd, node, score in beam}
        for _, node, score in beam:
            sims = graph.relationships.match((node, None),
                                             r_type='SIMILAR').all()
            for sim in sims:
                name = sim.end_node['name']
                s = score * sim['weight']
                if name not in possibility:
                    possibility[name] = (name, sim.end_node, s)
                else:
                    possibility[name] = (
                        name, sim.end_node,
                        ((s + possibility[name][-1]) / 2)**0.5
                    )
        beam = sorted(possibility.values(), key=lambda x: -x[-1])[:width]

    return [(wd, score) for wd, _, score in beam]

# %%
similar_words('桃李')
# Out:
# [('桃李', 1.0),
#  ('李', 0.7705247653801758),
#  ('春风', 0.7644110987657782),
#  ('美人', 0.748435975125649),
#  ('可怜', 0.7471985199658665),
#  ('燕', 0.7457832058205238),
#  ('年年', 0.7447035633415184),
#  ('颜', 0.7444414559524974),
#  ('长安', 0.7436674595971658),
#  ('黄金', 0.7431579091933598)]

# %% [markdown]
# 五、基于近义词关系的主题词挖掘
#
# 使用 neo4j 数据库的 gds 拓展，利用图算法进行聚类与主题词挖掘。

# %% [markdown]
# 调用 neo4j 的 Louvain 算法，对近义词进行聚类，并将聚类结果写入数据库中。

# %%
# 在 neo4j 中建立子图
if not graph.run("CALL gds.graph.exists('words')").data()[0]['exists']:
    graph.run("CALL gds.graph.create('words', 'Word', 'SIMILAR') YIELD nodeCount, relationshipCount")

# %%
graph.run("""CALL gds.louvain.write('words', { 
    writeProperty: 'topic'
}) YIELD communityCount, modularity, modularities""")
# Out:
#  communityCount |         modularity | modularities
# ----------------|--------------------|----------------------
#             125 | 0.7658609435171729 | [0.7658609435171729]

# %%
topics = graph.run("MATCH (w:Word) RETURN DISTINCT w.topic").to_ndarray(dtype=int).squeeze()
print(topics)
# Out:
# [ 6697   228  5783     8  7014  7205  5616  6652  6933  8081  7477  8749
#    707  6582  6704   215  5308    36   532  7262   238  7062  7930 10006
#   6217   180   621  7293  6603  7726  7143  5804  7185  7576   372  7789
#   7848  7502   643  7586  2414  7836   268  5072  8772  7371   135  6749
#   2448   284  8368  7271 10604  9125  9459  7846  8747  8250  2182  9406
#   7497   235  7285  4572  7867   275   745  8583   552  6769  6881  6512
#   8446  7795  7770  2076  8679 10142  7755  5916 10657  7144  6742  5618
#   2610   472 10208  7686  7359   676  5514   653  8329   686   692  2333
#   7131  2013  9039  2458  2681  7052  5827  4114  5426   581  7228  7598
#   5560  6959  2871  2950  7079  2601   193  5894  3058  6216  5729  7662
#   6800  5058   108  6853  7459]

# %%
from py2neo.bulk import merge_nodes

topic_nodes = ((int(topic), ) for topic in topics)
graph.run("CREATE INDEX IF NOT EXISTS FOR (t:Topic) ON (t.id)")
merge_nodes(graph.auto(), topic_nodes, ('Topic', 'id'), labels=('Topic', ), keys=('id', ))

# %%
graph.run(
    """MATCH (w:Word)
        OPTIONAL MATCH (t:Topic) WHERE w.topic=t.id
        MERGE (w)-[r:BELONG]->(t)"""
)
# Out:
# (No data)

# %% [markdown]
# 分别对每一类调用 neo4j 的 PageRank 算法，计算中心度 $\mathrm{PageRank}_w$，并将结果写入数据库中。

# %%
import tqdm
for topic in tqdm.tqdm(topics):
    graph.run(
        """CALL gds.pageRank.write({
        nodeQuery: 'MATCH (w:Word) WHERE w.topic = $topic RETURN id(w) as id',
        relationshipQuery: 'MATCH (w1:Word)-[r:SIMILAR]-(w2:Word) 
            WHERE w1.topic = $topic AND w2.topic = $topic 
            RETURN id(w1) AS source, id(w2) AS target, r.weight AS weight',
        writeProperty: 'pagerank', 
        relationshipWeightProperty: 'weight'
    }) YIELD nodePropertiesWritten, ranIterations""".replace(
            '$topic', str(topic)
        )
    )
# Out:
# 100%|██████████| 125/125 [00:12<00:00, 10.16it/s]

# %%
def topic_words(wd: str = '', topic: int = 0):
    topic = int(topic) or graph.nodes.match('Word', name=wd).first()['topic']
    nodes = graph.nodes.match('Word', topic=topic).order_by('-_.pagerank'
                                                            ).limit(10).all()
    return [node['name'] for node in nodes]

# %%
import tqdm
with open('topics.txt', 'w', encoding='utf-8') as f:
    for topic in tqdm.tqdm(topics):
        f.write(f"{topic} {' '.join(topic_words(topic=topic))}\n")
# Out:
# 100%|██████████| 125/125 [00:04<00:00, 26.72it/s]

# %%
import tqdm
with open('word_topics.csv', 'w', encoding='utf-8') as f:
    f.write("name,topic,pagerank\n")
    for wd in tqdm.tqdm(wds):
        node = graph.nodes.match('Word', name=wd).first()
        topic, pagerank = node['topic'], node['pagerank']
        f.write(f"{wd},{topic},{pagerank}\n")
# Out:
# 100%|██████████| 11745/11745 [01:05<00:00, 178.17it/s]

# %% [markdown]
# 六、将诗歌数据存入数据库中

# %%
graph.run("CREATE INDEX IF NOT EXISTS FOR (p:Author) ON (p.name)")
graph.run("CREATE INDEX IF NOT EXISTS FOR (p:Author) ON (p.id)")
graph.run("CREATE INDEX IF NOT EXISTS FOR (p:Poem) ON (p.id)")
graph.run("CREATE INDEX IF NOT EXISTS FOR (p:Poem) ON (p.title)")
graph.run("CREATE FULLTEXT INDEX paragraphs IF NOT EXISTS FOR (p:Poem) ON EACH [p.paragraphs, p.title]")
# Out:
# (No data)

# %%
import tqdm as tq
from itertools import islice

def batch_cut(it, batch_size=1000, tqdm=True):    
    l = len(it) // batch_size + 1
    rr = tq.trange(l) if tqdm else range(l)
    it = iter(it)
    for _ in rr:
        batch = islice(it, batch_size)
        if batch:
            yield batch

# %%
import json
from py2neo.bulk import merge_nodes

with open('data/authors.tang.json', 'r', encoding='utf-8') as f:
    authors = json.load(f)

for batch in batch_cut(authors):
    merge_nodes(graph.auto(), batch, ('Author', 'name'), labels=('Author', ))
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  9.32it/s]

# %%
import json
import tqdm as tq

def get_poems_info(max_n, start_n=0, tqdm=False):
    rr = tq.trange(start_n, max_n) if tqdm else range(start_n, max_n)
    for n in rr:
        with open(f'./data/poet.tang.{n}.json', 'r', encoding='utf-8') as f:
            poems = json.load(f)
        yield from poems

# %%
from py2neo.bulk import merge_nodes

N = 58

poems = get_poems_info(N)
batch_size = 1000

data = [
    {
        'id': poem['id'],
        'title': poem['title'],
        'author': poem['author'],
        'paragraphs': '\n'.join(poem['paragraphs']),
    } for poem in poems
]

for batch in batch_cut(data):
    merge_nodes(graph.auto(), batch, ('Poem', 'id'), labels=('Poem', ))

del data
# Out:
# 100%|██████████| 58/58 [00:05<00:00, 10.39it/s]

# %%
from py2neo.bulk import merge_relationships

N = 58

poems = get_poems_info(N)
batch_size = 1000

data = [(poem['author'], tuple(), poem['id']) for poem in poems]

for batch in batch_cut(data):
    merge_relationships(
        graph.auto(),
        batch,
        'WRITE',
        start_node_key=('Author', 'name'),
        end_node_key=('Poem', 'id'),
        keys=[]
    )

del data
# Out:
# 100%|██████████| 58/58 [00:02<00:00, 22.16it/s]

# %%
from py2neo.bulk import merge_relationships
from collections import Counter

N = 58
wds_set = set(wds)


def rels_poem_word():
    for poem in get_poems_info(N, tqdm=True):
        s = ''.join(poem['paragraphs'])
        c = Counter(''.join(wd) for wd in chain(zip(s, s[1:]), s))
        for wd, count in c.items():
            if wd in wds_set:
                yield poem['id'], (count, ), wd


data = list(rels_poem_word())

for batch in batch_cut(data):
    merge_relationships(
        graph.auto(),
        batch,
        'CONTAIN',
        start_node_key=('Poem', 'id'),
        end_node_key=('Word', 'name'),
        keys=['count']
    )

del data
# Out:
# 100%|██████████| 58/58 [00:05<00:00,  9.70it/s]
# 100%|██████████| 3100/3100 [02:19<00:00, 22.19it/s]

# %% [markdown]
# 七、计算诗和词语的匹配度
#
# $$\mathrm{Match}[P,w]=\frac{\alpha}{|P|}\sum_{w'\in \mathcal{S}\cap P}\mathrm{v}_w\cdot\mathrm{v}_{w'} +
# \frac{1-\alpha}{|\mathcal{T}_w\cap P|}\sum_{w'\in\mathcal{T}_w\cap P}\ln(1+\mathrm{PageRank}_{w'})$$
#
# 其中$P$为一首诗包含的所有词语，$w$为一个词语，$\mathcal{S}$为$w$的近义词集合，$\mathcal{T}$为$w$所在主题的词语集合。
#
# $\alpha$为比例系数，经实验取0.85。

# %% [markdown]
# 第一项：基于近义词的文本匹配：
#
# $$\frac{1}{|P|}\sum_{w'\in \mathcal{S}\cap P}\mathrm{v}_w\cdot\mathrm{v}_{w'}$$
#
# 一首诗包含某个词语的近义词越多，就认为这首诗和这个词的匹配度越高。

# %%
import numpy as np
from py2neo.bulk import merge_relationships
from itertools import chain

N = 58
K = 10

wds_inv = {wd: index for index, wd in enumerate(wds)}
num = connection_coo.shape[0]
mmap = np.zeros(connection_coo.shape)
for i, wd in enumerate(tqdm.tqdm(wds)):
    topk = np.argpartition(-connection_coo[i], K)[:K]
    mmap[i, topk] = connection_coo[i, topk]
    mmap[i, i] = 0


def rels_poem_word():
    for poem in get_poems_info(N, tqdm=True):
        s = ''.join(poem['paragraphs'])
        c = set(''.join(wd) for wd in chain(zip(s, s[1:]), s))
        c = [wd for wd in c if wd in wds_inv]
        for wd in c:            
            matching = sum(float(mmap[wds_inv[wd], wds_inv[wd2]]) for wd2 in c)
            yield poem['id'], (float(matching) / len(c), ), wd


data = list(rels_poem_word())

for batch in batch_cut(data):
    merge_relationships(
        graph.auto(),
        batch,
        'CONTAIN',
        start_node_key=('Poem', 'id'),
        end_node_key=('Word', 'name'),
        keys=['matching']
    )

del data
# Out:
# 100%|██████████| 11745/11745 [00:01<00:00, 8666.58it/s]
# 100%|██████████| 58/58 [01:55<00:00,  1.99s/it]
# 100%|██████████| 3100/3100 [02:39<00:00, 19.42it/s]

# %%
graph.run("MATCH ()-[r:CONTAIN]-() WHERE r.matching IS NULL SET r.matching=0.0")
# Out:
# (No data)

# %% [markdown]
# 第二项：基于主题词模型的文本匹配：
#
# $$\frac{1}{|\mathcal{T}_w\cap P|}\sum_{w'\in\mathcal{T}_w\cap P}\ln(1+\mathrm{PageRank}_{w'})$$
#
# 基于诗中包含词语所属主题与词语的 PageRank，计算每首诗与主题的关联度。

# %%
import pandas as pd
from collections import defaultdict
from py2neo.bulk import merge_relationships
from itertools import chain

df = pd.read_csv('word_topics.csv')
topics = df['topic']
pr = df['pagerank']
wds_inv = {wd: index for index, wd in enumerate(wds)}

N = 58


def rels_poem_topic():
    for poem in get_poems_info(N, tqdm=True):
        s = ''.join(poem['paragraphs'])
        c = set(''.join(wd) for wd in chain(zip(s, s[1:]), s))
        c = [wd for wd in c if wd in wds_inv]
        relevance = defaultdict(float)
        counts = defaultdict(int)
        for wd in c:
            index = wds_inv[wd]            
            relevance[topics[index]] += np.log(pr[index] + 1)
            counts[topics[index]] += 1
        for topic, rele in relevance.items():
            yield poem['id'], (float(rele) / counts[topic], ), int(topic)


data = list(rels_poem_topic())

for batch in batch_cut(data):
    merge_relationships(
        graph.auto(),
        batch,
        'RELEVANT',
        start_node_key=('Poem', 'id'),
        end_node_key=('Topic', 'id'),
        keys=['relevance']
    )

del data
# Out:
# 100%|██████████| 58/58 [00:39<00:00,  1.46it/s]
# 100%|██████████| 498/498 [00:19<00:00, 24.92it/s]

# %%
import pandas as pd
from collections import defaultdict
from py2neo.bulk import merge_relationships
from itertools import chain
import numpy as np

df = pd.read_csv('word_topics.csv')
topics = df['topic']
pr = df['pagerank']
wds_inv = {wd: index for index, wd in enumerate(wds)}

N = 58


def rels_poem_topic_word():
    for poem in get_poems_info(N, tqdm=True):
        s = ''.join(poem['paragraphs'])
        c = set(''.join(wd) for wd in chain(zip(s, s[1:]), s))
        c = [wd for wd in c if wd in wds_inv]
        relevance = defaultdict(float)
        counts = defaultdict(int)
        for wd in c:
            index = wds_inv[wd]
            relevance[topics[index]] += float(np.log(pr[index] + 1))
            counts[topics[index]] += 1
        for wd in c:
            index = wds_inv[wd]
            rele = relevance[topics[index]]
            yield poem['id'], (float(rele) / counts[topics[index]], ), wd


data = list(rels_poem_topic_word())

for batch in batch_cut(data):
    merge_relationships(
        graph.auto(),
        batch,
        'CONTAIN',
        start_node_key=('Poem', 'id'),
        end_node_key=('Word', 'name'),
        keys=['relevance']
    )

del data
# Out:
# 100%|██████████| 58/58 [01:01<00:00,  1.06s/it]
# 100%|██████████| 3100/3100 [02:38<00:00, 19.50it/s]

# %%
graph.run("MATCH ()-[r:CONTAIN]-() WHERE r.relevance IS NULL SET r.relevance=0.0")
# Out:
# (No data)

# %% [markdown]
# 八、基于中心性与影响力的诗歌离线排名
#
# 按照诗歌所包含词语的相似性，来判断诗歌的相似性。在相似网络中的 PageRank 越高，影响力越高。
#
# 以此为依据，计算搜索结果中的诗歌排名：
#
# $$\mathrm{Score}[P, w]=\sqrt{\ln(1+\mathrm{PageRank}[P])}\times \mathrm{Match}[P, w]$$

# %%
import tqdm
import pandas as pd
import numpy as np
from itertools import chain

df = pd.concat([pd.read_json(f'data/poet.tang.{n}.json') for n in range(58)])
df.index = range(len(df))
wds_inv = {wd: index for index, wd in enumerate(wds)}

pwds = np.zeros((len(df), 200))
for i, row in tqdm.tqdm(df.iterrows(), total=len(df)):
    s = ''.join(row['paragraphs'])
    c = set(''.join(wd) for wd in chain(zip(s, s[1:]), s))
    c = [wds_inv[wd] for wd in c if wd in wds_inv]
    for wdi in c:
        pwds[i] += vectors_coo[wdi]
# Out:
# 100%|██████████| 57612/57612 [00:12<00:00, 4484.16it/s]

# %%
from sklearn.decomposition import PCA

pwds = PCA(n_components=200).fit_transform(pwds)
norms = np.linalg.norm(pwds, axis=1)[:, np.newaxis]
ppwds = np.divide(pwds, norms, out=pwds, where=norms != 0)

# %%
import numpy as np
import tqdm

K = 16
kmost = np.zeros((len(pwds), K), dtype=int)
for i, pvec in enumerate(tqdm.tqdm(pwds)):
    sims = pwds.dot(pvec)
    kmost[i] = (-sims).argpartition(K)[:K]

print(kmost[:10])
# Out:
# 100%|██████████| 57612/57612 [04:15<00:00, 225.17it/s]
# [[    0  4035 52162 10305   144  3268  3411  2885 29669 23100  4932  2765
#   41206  4882 17367 31517]
#  [  437   221 27301   570   761   519     1   384 50366   242   748  2470
#   17550   756 25246  2448]
#  [  734    57     2   791   810  2476   844 11051  8477   489 18134  2554
#   27301   730 13381   615]
#  [ 2604 52597   576     3 32178   396  2553  2891  2554  2890 52164 52162
#    4053  2886   716  5294]
#  [52164   305  3827  3264     4    74  3991 50509  3997  3587    76  5209
#    3486  4224  5299  3460]
#  [23787  8982  4154 13031 41277     5 17459 17323 28696 43171 39555 25844
#    6714 25407 32420   199]
#  [    6 41154  2587 52164  2884  5831 50509 17454    46  5319 44900 17421
#    2592  4932 28295 17094]
#  [28057   575   430   844     7   678   620   402  2462   395   474   437
#     791  4507   418  3891]
#  [    8  8878  6977 29428  1975 29388 49182 13329  1417 18741  2213 39863
#   12047 20844 43917 16413]
#  [ 2962 47288 43617  2960 17437 18580 47301   120 47297     9  7681 17176
#    2586   117 49946 17338]]

# %%
import tqdm
import numpy as np
from py2neo.bulk import merge_relationships
from itertools import islice

ids = df['id']
rels = []
for i, topk in enumerate(tqdm.tqdm(kmost)):
    for j in topk:
        if i != j:
            rels.append((ids[i], (float(pwds[i].dot(pwds[j])), ), ids[j]))

stream = iter(rels)
batch_size = 1000

for _ in tqdm.trange(len(rels) // batch_size + 1):
    batch = islice(stream, batch_size)
    if batch:
        merge_relationships(
            graph.auto(),
            batch,
            'INFLUENCE',
            start_node_key=('Poem', 'id'),
            end_node_key=('Poem', 'id'),
            keys=['weight']
        )
# Out:
# 100%|██████████| 57612/57612 [00:09<00:00, 5911.99it/s]
# 100%|██████████| 865/865 [01:19<00:00, 10.87it/s]

# %%
# 在 neo4j 中建立子图
if not graph.run("CALL gds.graph.exists('poems')").data()[0]['exists']:
    graph.run("""CALL gds.graph.create(
        'poems', 
        'Poem', 
        { INFLUENCE: { orientation: 'UNDIRECTED', properties: "weight" } }
    ) YIELD nodeCount, relationshipCount""")

# %%
graph.run(
    """CALL gds.pageRank.write('poems', {
        writeProperty: 'pagerank', 
        relationshipWeightProperty: 'weight'
    }) YIELD nodePropertiesWritten, ranIterations"""
)
graph.run("MATCH (p:Poem) SET p.pagerank=log(1+p.pagerank)^0.5")
# Out:
# (No data)

# %% [markdown]
# 九、根据匹配度，查询诗歌

# %%
def match_poems(wd, start=0, count=10):
    return graph.run(
        """MATCH (p:Poem)-[r:CONTAIN]->(:Word {name:'$wd'})
            WITH p.title AS title, p.author AS author, p.paragraphs AS paragraphs, 
                p.pagerank * (r.matching*0.85 + r.relevance*0.15) AS score
            RETURN title, author, paragraphs, score
            ORDER BY score DESC SKIP $s LIMIT $e
        """.replace("$wd", str(wd)).replace("$s", str(start)).replace("$e", str(count))
    ).to_data_frame()

# %%
match_poems('东风', start=30, count=10)
# Out:
#         title author                                         paragraphs  \
# 0         折杨柳     李白  垂杨拂绿水，摇艳东风年。\n花明玉关雪，叶暖金窗烟。\n美人结长想，对此心凄然。\n攀条折春...
# 1     早春浐水送友人    温庭筠  青门烟野外，渡浐送行人。\n鸭卧溪沙暖，鸠鸣社树春。\n残波青有石，幽草绿无尘。\n杨柳东风...
# 2    杂曲歌辞 独不见    杨巨源  东风艳阳色，柳绿花如霰。\n竞理同心鬟，争持合欢扇。\n香传贾娘手，粉离何郎面。\n最恨卷帘...
# 3     醉后赠从甥高镇     李白  马上相逢揖马鞭，客中相见客中怜。\n欲邀击筑悲歌饮，正值倾家无酒钱。\n江东风光不借人，枉杀...
# 4        春游值雨     张旭                 欲寻轩槛列清尊，江上烟云向晚昏。\n须倩东风吹散雨，明朝却待入华园。
# 5      东风二章 一    欧阳詹  东风叶时，匪沃匪飘。\n莫雪凝川，莫阴沍郊。\n朝不徯夕乃销，东风之行地上兮。\n上德临慝，...
# 6       小重山 一    薛昭蕴  春到长门春草青，玉阶华露滴，月胧明。\n东风吹断紫箫声，宫漏促，帘外晓啼莺。\n愁极梦难成，...
# 7       南阳道中作     窦巩  东风雨洗顺阳川，蜀锦花开绿草田。\n彩雉鬬时频驻马，酒旗翻处亦留钱。\n新晴日照山头雪，薄暮...
# 8     柳枝词十首 四     徐铉                 绿水成文柳带摇，东风初到不鸣条。\n龙舟欲过偏留恋，万缕轻丝拂御桥。
# 9  杂曲歌辞 杨柳枝 三    温庭筠                 苏小门前柳万条，毵毵金线拂平桥。\n黄莺不语东风起，深闭朱门伴细腰。
#
#       score
# 0  0.125150
# 1  0.124896
# 2  0.124884
# 3  0.124327
# 4  0.123736
# 5  0.122826
# 6  0.122730
# 7  0.122572
# 8  0.122170
# 9  0.121657

# %%
wds_set = set(wds)
def pull_words(s):    
    c = set(''.join(wd) for wd in chain(zip(s, s[1:]), s))
    return [wd for wd in c if wd in wds_set]

# %%
def match_poems_ex(word, start=0, count=10):
    return graph.run(
        """MATCH (p:Poem)-[r:CONTAIN]->(w:Word)
            WHERE w.name IN ['$wds']
            WITH p.title AS title, p.author AS author, p.paragraphs AS paragraphs, 
                p.pagerank * (r.matching*0.85 + r.relevance*0.15) AS score
            RETURN title, author, paragraphs, score
            ORDER BY score DESC SKIP $s LIMIT $e
        """.replace("$wds",
                    "','".join(pull_words(word)
                             )).replace("$s",
                                        str(start)).replace("$e", str(count))
    ).to_data_frame()

# %%
match_poems_ex('刻晴')
# Out:
#           title author                                         paragraphs  \
# 0             句     李洞                                           鱼弄晴波影上帘。
# 1            桃花     薛能  香色自天种，千年岂易逢。\n开齐全未落，繁极欲相重。\n泠湿朝如淡，晴干午更浓。\n风光新社...
# 2         泊凫矶江馆     赵嘏  风雪晴来岁欲除，孤舟晚下意何如。\n月当轩色湖平后，雁断云声夜起初。\n傍晓管弦何处静，犯寒...
# 3            仙掌     齐己  峭形寒倚夕阳天，毛女莲花翠影连。\n云外自为高出手，人间谁合鬬挥拳。\n鹤抛青汉来岩桧，僧隔...
# 4         自和次前韵    陆龟蒙  命既时相背，才非世所容。\n著书粮易绝，多病药难供。\n梦为怀山数，愁因戒酒浓。\n鸟媒呈不...
# 5      游崔监丞城南别业    刘得仁  门与青山近，青山复几重。\n雪融皇子岸，春浥翠微峰。\n地有经冬草，林无未老松。\n竹寒溪隔...
# 6       四明山诗 石窗    陆龟蒙  石窗何处见，万仞倚晴虚。\n积霭迷青璅，残霞动绮疏。\n山应列圆峤，宫便接方诸。\n祗有三奔...
# 7  酬张少尹秋日凤翔西郊见寄     耿𣲗  鼎气孕河汾，英英济旧勋。\n刘生曾任侠，张率自能文。\n官佐征西府，名齐将上军。\n秋山遥出...
# 8        送王昌涉侍御     张祜  十里指东平，军前首出征。\n诸侯青服旧，御史紫衣荣。\n入陈枭心死，分围虎力生。\n画时安楚...
# 9         五月水边柳    张又新  结根挺涯涘，垂影覆清浅。\n睡脸寒未开，懒腰晴更软。\n摇空条已重，拂水带方展。\n似醉烟景...
#
#       score
# 0  0.220970
# 1  0.207983
# 2  0.205527
# 3  0.198443
# 4  0.195114
# 5  0.186493
# 6  0.180621
# 7  0.179874
# 8  0.178809
# 9  0.176507
